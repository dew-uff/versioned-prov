# %%
import sys
sys.path.insert(0, '..')

# %load_ext tools.prov_magics
import tools.view.intertwined_prov

# %%
import importlib
import tools.annotations as prov
importlib.reload(prov)
# %run ../scripts/int_floydwarshall.py
# Out:
# 3
