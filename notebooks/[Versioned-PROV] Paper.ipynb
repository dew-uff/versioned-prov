# %%
# %%javascript
# console.log("Teste");
# require(['notebook/js/codecell'], function(codecell) {
#   codecell.CodeCell.options_default.highlight_modes['text/x-rustsrc'] = {'reg':[/^%%provn/]} ;
#   Jupyter.notebook.events.one('kernel_ready.Kernel', function(){
#   Jupyter.notebook.get_cells().map(function(cell){
#       if (cell.cell_type == 'code'){ cell.auto_highlight(); } }) ;
#   });
# });

# %%
# %reload_ext extensible_provn.prov_magics
import extensible_provn.view.versioned_prov
import extensible_provn.view.prov_dictionary
BASE = "../generated/paper"

# %% [markdown]
# # PROV

# %% [markdown]
# - [L2#1: matrix0#1, matrix1#1, matrix2#1, matrix20#1, matrix21#1, matrix22#1, result#1, dist#1](../generated/plain_prov/temp/L2__list_definition__assign.provn)
# - [L12#2: disti#2](../generated/plain_prov/temp/L12__access__assign_2.provn)
# - [L13#5: j#5](../generated/plain_prov/temp/L13__loop_access_5.provn)
# - [L15#2: ikj#2](../generated/plain_prov/temp/L15__access__access__operation__assign_2.provn)
# - [L16#2: disti@j#2](../generated/plain_prov/temp/L16__access_2.provn)
# - [L17#1](../generated/plain_prov/temp/L17__part_assign_with_propagation.provn)

# %%
# %%provn -o $BASE/plain_prov -e png svg pdf provn dot -s paper -r BT
# newrank=true;
# splines = "spline"
#
# subgraph cluster_0 {
#     labeljust="r"
#     labelloc="b"
#     margin="2"
#     color = "#333333"
#     fontcolor = "#333333"
#     fontsize = "36"
#     label = "A";
#     "g/disti@j#3"; "g/disti@j#3-attrs"
#     "g/assign11"; "g/assign11-attrs"
#     "g/ikj#2"; "g/ikj#2-attrs"
#     "g/j#5"; "g/j#5-attrs"
#     "g/disti@j#2"; "g/disti@j#2-attrs"
#     "g/disti#2"; "g/disti#2-attrs"
# }
# subgraph cluster_1 {
#     labeljust="r"
#     labelloc="b"
#     margin="2"
#     color = "#333333"
#     fontcolor = "#333333"
#     fontsize = "36"
#     label = "B";
#     "g/matrix0#1"
#     "g/matrix1#1"
#     "g/matrix2#1"
#     "g/matrix20"
#     "g/matrix21"
#     "g/matrix22"
#     "g/dist#1"
#     "g/result#1"
# }
#
# subgraph cluster_2 {
#     labeljust="r"
#     labelloc="b"
#     margin="2"
#     color = "#333333"
#     fontcolor = "#333333"
#     fontsize = "36"
#     label = "C";
#     "g/disti#3"; "g/disti#3-attrs"
#     "g/result#2"; "g/result#2-attrs"
#     "g/dist#2"; "g/dist#2-attrs"
# }
# ##H##
# document
# default <g>
#
# // L2#1
# entity(matrix0#1, [value="[0, 1, 4]",type="script:list",label="[0, 1, 4]",script:line="3", dot:hide2="true"])
# entity(matrix1#1, [value="[10000, 0, 2]",type="script:list",label="[m, 0, 2]",script:line="4", dot:hide2="true"])
# entity(matrix2#1, [value="[2, 10000, 0]",type="script:list",label="[2, m, 0]",script:line="5", dot:hide2="true"])
# entity(matrix20, [value="2",type="item",label="2",script:line="5",dot:hide2="true"])
# hadMember(matrix2#1, matrix20, [dot:hide2="true"])
# entity(matrix21, [value="10000",type="item",label="m",script:line="5",dot:hide2="true"])
# hadMember(matrix2#1, matrix21, [dot:hide2="true"])
# entity(matrix22, [value="0",type="item",label="0",script:line="5",dot:hide2="true"])
# hadMember(matrix2#1, matrix22, [dot:hide2="true"])
#
# //entity(dist#1, [value="[[0, 1, 4], [10000, 0, 2], [2, 10000, 0]]",type="script:name",label="dist",script:line="2", dot:hide2="true"])
# entity(dist#1, [value="[[...]]",type="script:name",label="dist",script:line="2", dot:hide2="true"])
# hadMember(dist#1, matrix0#1, [dot:hide2="true"])
# hadMember(dist#1, matrix1#1, [dot:hide2="true"])
# hadMember(dist#1, matrix2#1, [dot:hide2="true"])
#
# //entity(result#1, [value="[[0, 1, 4], [10000, 0, 2], [2, 10000, 0]]",type="script:name",label="result",script:line="2", dot:hide2="true"])
# entity(result#1, [value="[[...]]",type="script:name",label="result",script:line="2", dot:hide2="true"])
# hadMember(result#1, matrix0#1, [dot:hide2="true"])
# hadMember(result#1, matrix1#1, [dot:hide2="true"])
# hadMember(result#1, matrix2#1, [dot:hide2="true"])
#
# // L12#2
# entity(disti#2, [value="[2, 10000, 0]",type="script:name",label="disti",script:line="12"])
# hadMember(disti#2, matrix20, [dot:hide2="true"])
# hadMember(disti#2, matrix21, [dot:hide2="true"])
# hadMember(disti#2, matrix22, [dot:hide2="true"])
#
# // L13#2
# entity(j#5, [value="1",type="script:name",label="j",script:line="13"])
#
# // L15#2
# entity(ikj#2, [value="3",type="script:name",label="ikj",script:line="15"])
#
# // L16#2
# entity(disti@j#2, [value="10000",type="script:access",label="disti[j]",script:line="16",dot:hide2="~attr"])
#
# // L17#1
# entity(disti#3, [value="[2, 3, 0]",type="script:list",label="disti",script:line="17",dot:specific="true"])
# hadMember(disti#3, matrix20, [dot:specific="true"])
# hadMember(disti#3, matrix22, [dot:specific="true"])
# hadMember(disti#3, disti@j#3, [dot:specific="true"])
# wasDerivedFrom(disti#3, disti#2, assign11, g40, u43, [dot:specific="true"])
# wasDerivedFrom(disti#3, ikj#2, assign11, g40, u42, [dot:specific="true"])
#
# //entity(dist#2, [value="[[0, 1, 4], [10000, 0, 2], [2, 3, 0]]",type="list",label="dist",script:line="17",dot:specific="true"])
# entity(dist#2, [value="[[...]]",type="list",label="dist",script:line="17",dot:specific="true"])
# hadMember(dist#2, matrix0#1, [dot:specific="true"])
# hadMember(dist#2, matrix1#1, [dot:specific="true"])
# hadMember(dist#2, disti#3, [dot:specific="true"])
# wasDerivedFrom(dist#2, dist#1, assign11, g41, u44, [dot:specific="true"])
# wasDerivedFrom(dist#2, ikj#2, assign11, g41, u42, [dot:specific="true"])
#
# //entity(result#2, [value="[[0, 1, 4], [10000, 0, 2], [2, 3, 0]]",type="name",label="result",script:line="17",dot:specific="true"])
# entity(result#2, [value="[[...]]",type="name",label="result",script:line="17",dot:specific="true"])
# hadMember(result#2, matrix0#1, [dot:specific="true"])
# hadMember(result#2, matrix1#1, [dot:specific="true"])
# hadMember(result#2, disti#3, [dot:specific="true"])
# wasDerivedFrom(result#2, result#1, assign11, g42, u45, [dot:specific="true"])
# wasDerivedFrom(result#2, ikj#2, assign11, g42, u42, [dot:specific="true"])
#
# entity(disti@j#3, [value="3",type="script:access",label="disti[j]",script:line="17"])
# activity(assign11, [type="script:assign"])
# wasDerivedFrom(disti@j#3, ikj#2, assign11, g43, u42)
# used(assign11, j#5, -)
# used(assign11, disti@j#2, -,[dot:hide2="true"])
# endDocument
# ##F##
#
# //{rank=same "g/disti#3" "g/disti@j#3"}
# {rank=same "g/disti#2" "g/ikj#2"}
# {rank=same "g/dist#2" "g/result#2-attrs" "g/result#2" "g/dist#2-attrs"}
# {rank=same "g/disti#3" "g/disti#3-attrs" "g/disti@j#3" "g/disti@j#2-attrs"}

# %% [markdown]
# # PROV-Dictionary

# %% [markdown]
# - [L2#1: matrix0#1, matrix1#1, matrix2#1, matrix20#1, matrix21#1, matrix22#1, result#1, dist#1](../generated/prov_dictionary/temp/L2__list_definition__assign.provn)
# - [L12#2: disti#2](../generated/prov_dictionary/temp/L12__access__assign_2.provn)
# - [L13#5: j#5](../generated/prov_dictionary/temp/L13__loop_access_5.provn)
# - [L15#2: ikj#2](../generated/prov_dictionary/temp/L15__access__access__operation__assign_2.provn)
# - [L16#2: disti@j#2](../generated/prov_dictionary/temp/L16__access_2.provn)
# - [L17#1](../generated/prov_dictionary/temp/L17__part_assign_with_propagation.provn)

# %%
# %%provn -o $BASE/prov_dictionary -e png svg pdf provn dot -s paper
# newrank=true;
# splines = "spline"
# ranksep = "0.1"
# subgraph cluster_0 {
#     labeljust="r"
#     labelloc="b"
#     margin="2"
#     ranksep = "0.1"
#     color = "#333333"
#     fontcolor = "#333333"
#     fontsize = "36"
#     label = "A";
#     "g/disti@j#3"; "g/disti@j#3-attrs"
#     "g/assign11"; "g/assign11-attrs"
#     "g/ikj#2"; "g/ikj#2-attrs"
#     "g/j#5"; "g/j#5-attrs"
#     "g/disti@j#2"; "g/disti@j#2-attrs"
#     "g/disti#2"; "g/disti#2-attrs"
#     "bn3"
# }
# subgraph cluster_1 {
#     ranksep = "0.1"
#     labeljust="r"
#     labelloc="b"
#     margin="2"
#     color = "#333333"
#     fontcolor = "#333333"
#     fontsize = "36"
#     label = "B";
#     "g/matrix0#1"
#     "g/matrix1#1"
#     "g/matrix2#1"
#     "g/matrix20"
#     "g/matrix21"
#     "g/matrix22"
#     "g/dist#1"
#     "g/result#1"
#     "g/empty"
#     "bn0"
#     "bn1"
#     "bn2"
# }
#
# subgraph cluster_2 {
#     ranksep = "0.1"
#     labeljust="r"
#     labelloc="b"
#     margin="2"
#     color = "#333333"
#     fontcolor = "#333333"
#     fontsize = "36"
#     label = "C";
#     "g/disti#3"; "g/disti#3-attrs"
#     "g/result#2"; "g/result#2-attrs"
#     "g/dist#2"; "g/dist#2-attrs"
#     "bn4"
#     "bn5"
#     "bn6"
# }
# ##H##
# document
# default <g>
# // empty
# entity(empty, [value="[]",type="EmptyDictionary",dot:hide2="true"])
# // L2#1
# entity(matrix0#1, [value="[0, 1, 4]",type="Dictionary",label="[0, 1, 4]",script:line="3",dot:hide2="true"])
# entity(matrix1#1, [value="[10000, 0, 2]",type="Dictionary",label="[m, 0, 2]",script:line="4",dot:hide2="true"])
# entity(matrix2#1, [value="[2, 10000, 0]",type="Dictionary",label="[2, m, 0]",script:line="5",dot:hide2="true"])
# entity(matrix20, [value="2",type="item",label="2",script:line="5",dot:hide2="true"])
# entity(matrix21, [value="10000",type="item",label="m",script:line="5",dot:hide2="true"])
# entity(matrix22, [value="0",type="item",label="0",script:line="5",dot:hide2="true"])
# derivedByInsertionFrom(matrix2#1, empty, {("0", matrix20), ("1", matrix21), ("2", matrix22)}, [dot:hide2="true"])
#
# //entity(dist#1, [value="[[0, 1, 4], [10000, 0, 2], [2, 10000, 0]]",type="Dictionary",label="dist",script:line="2",dot:hide2="true"])
# entity(dist#1, [value="[[...]]",type="Dictionary",label="dist",script:line="2",dot:hide2="true"])
# derivedByInsertionFrom(dist#1, empty, {("0", matrix0#1), ("1", matrix1#1), ("2", matrix2#1)}, [dot:hide2="true"])
#
# //entity(result#1, [value="[[0, 1, 4], [10000, 0, 2], [2, 10000, 0]]",type="Dictionary",label="result",script:line="2",dot:hide2="true"])
# entity(result#1, [value="[[...]]",type="Dictionary",label="result",script:line="2",dot:hide2="true"])
# derivedByInsertionFrom(result#1, empty, {("0", matrix0#1), ("1", matrix1#1), ("2", matrix2#1)}, [dot:hide2="true"])
#
# // L12#2
# entity(disti#2, [value="[2, 10000, 0]",type="Dictionary",label="disti",script:line="12"])
# derivedByInsertionFrom(disti#2, empty, {("0", matrix20), ("1", matrix21), ("2", matrix22)}, [dot:hide2="true"])
#
# // L13#2
# entity(j#5, [value="1",type="script:name",label="j",script:line="13"])
#
# // L15#2
# entity(ikj#2, [value="3",type="script:name",label="ikj",script:line="15"])
#
# // L16#2
# entity(disti@j#2, [value="10000",type="script:access",label="disti[j]",script:line="16",dot:hide2="~attr"])
#
# // L17#1
#
#
#
# entity(disti#3, [value="[2, 3, 0]",type="Dictionary",label="disti",script:line="17",dot:specific="true"])
# derivedByInsertionFrom(disti#3, disti#2, {("1", disti@j#3)}, [dot:specific="true"])
# wasDerivedFrom(disti#3, disti#2, assign11, g40, u43, [dot:specific="true"])
# wasDerivedFrom(disti#3, ikj#2, assign11, g40, u42, [dot:specific="true"])
#
# //entity(dist#2, [value="[[0, 1, 4], [10000, 0, 2], [2, 3, 0]]",type="Dictionary",label="dist",script:line="17",dot:specific="true"])
# entity(dist#2, [value="[[...]]",type="Dictionary",label="dist",script:line="17",dot:specific="true"])
# derivedByInsertionFrom(dist#2, dist#1, {("2", disti#3)}, [dot:specific="true"])
# wasDerivedFrom(dist#2, dist#1, assign11, g41, u44, [dot:specific="true"])
# wasDerivedFrom(dist#2, ikj#2, assign11, g41, u42, [dot:specific="true"])
#
# //entity(result#2, [value="[[0, 1, 4], [10000, 0, 2], [2, 3, 0]]",type="Dictionary",label="result",script:line="17",dot:specific="true"])
# entity(result#2, [value="[[...]]",type="Dictionary",label="result",script:line="17",dot:specific="true"])
# derivedByInsertionFrom(result#2, result#1, {("2", disti#3)}, [dot:specific="true"])
# wasDerivedFrom(result#2, result#1, assign11, g42, u45, [dot:specific="true"])
# wasDerivedFrom(result#2, ikj#2, assign11, g42, u42, [dot:specific="true"])
#
# entity(disti@j#3, [value="3",type="script:access",label="disti[j]",script:line="17"])
# activity(assign11, [type="script:assign"])
# wasDerivedFrom(disti@j#3, ikj#2, assign11, g43, u42)
# used(assign11, j#5, -)
# used(assign11, disti@j#2, -,[dot:hide2="true"])
# endDocument
# ##F##
# {rank=same "g/disti#2" "g/ikj#2"}
# {rank=same "g/disti@j#3-attrs" "g/disti@j#3"}
# //{rank=same "g/disti@j#2-attrs" "bn1"}
# {rank=same "bn4" "g/assign11" "g/result#1" "g/dist#1"}
# //{rank=same "g/disti#3" "g/disti#3-attrs" }
# {rank=same "bn3" "bn0"}
# {rank=same "g/dist#2" "g/result#2-attrs" "g/result#2"}
# "g/disti@j#2" -> "g/disti@j#2-attrs" [style="invis"]
# "g/disti@j#2" -> "g/disti@j#2-attrs" [style="invis"]
# "g/dist#2" -> "g/dist#2-attrs"  [style=invis]
# "g/disti#3" -> "g/disti#3-attrs"  [style=invis]
# "g/disti#2" -> "g/disti#2-attrs"  [style=invis]
# "g/dist#2" -> "g/result#2" -> "g/result#2-attrs" [style="invis"]
# {rank=same "g/assign11" "g/dist#2-attrs"}

# %% [markdown]
# # Versioned-PROV

# %% [markdown]
# - [L1#1: m](../generated/versioned_prov/temp/L1__assign.provn)
# - [L2#1: 0, 2, matrix, matrix0, matrix1, matrix2, dist](../generated/versioned_prov/temp/L2__list_definition__assign.provn)
# - [L12#2: dist@i#2, disti#2](../generated/versioned_prov/temp/L12__access__assign_2.provn)
# - [L13#5: j#5](../generated/versioned_prov/temp/L13__loop_access_5.provn)
# - [L15#2: ikj#2](../generated/versioned_prov/temp/L15__access__access__operation__assign_2.provn)
# - [L16#2: disti@j#2](../generated/versioned_prov/temp/L16__access_2.provn)
# - [L17#1](../generated/versioned_prov/temp/L17__part_assign_with_propagation.provn)

# %%
# %%provn -o $BASE/versioned_prov -e png svg pdf provn dot -s paper
# newrank=true;
# splines = "spline"
#
# subgraph cluster_0 {
#     labeljust="r"
#     labelloc="b"
#     margin="2"
#     color = "#333333"
#     fontcolor = "#333333"
#     fontsize = "36"
#     label = "A";
#     "g/disti@j#3"; "g/disti@j#3-attrs"
#     "g/assign11"; "g/assign11-attrs"
#     "g/ikj#2"; "g/ikj#2-attrs"
#     "g/j#5"; "g/j#5-attrs"
#     "g/disti@j#2"; "g/disti@j#2-attrs"
#     "g/disti#2"; "g/disti#2-attrs"
#     "bn0"
#
# //    {rank=same "g/disti@j#3" "g/disti@j#3-attrs"}
#     {rank=same "g/disti#2" "g/ikj#2"}
# }
# subgraph cluster_1 {
#     ranksep = "0.1"
#     labeljust="r"
#     labelloc="b"
#     margin="2"
#     color = "#333333"
#     fontcolor = "#333333"
#     fontsize = "36"
#     label = "B";
#     "g/dist@i#2"
#     "g/matrix2#1", "g/matrix2#1-attrs"
#     "g/m"
#     "g/0"
#     "g/2"
# }
# {rank=same "g/matrix2#1" "g/disti@j#3" "g/disti@j#3-attrs" "g/matrix2#1-attrs"}
# {rank=same "g/disti#2" "g/dist@i#2"}
# "g/2" -> "g/m" -> "g/0" [style="invis"]
# {rank=same "g/0" "g/m" "g/2"}
# "g/matrix2#1-attrs" -> "g/0" [style="invis"]
#
# ##H##
# document
# default <g>
# // L1#1
# entity(m, [value="10000",type="script:name",label="m",script:line="1",dot:hide2="true"])
#
# // L2#1
# entity(0, [value="0",type="script:literal",script:line="3",dot:hide2="true"])
# entity(2, [value="2",type="script:literal",script:line="4",dot:hide2="true"])
# //entity(matrix, [value="[[...]]",type="script:list",label="[[...]]",script:line="2",dot:hide2="true"])
# //entity(matrix0, [value="[0, 1, 4]",type="script:list",label="[0, 1, 4]",script:line="3",dot:hide2="true"])
# //hadMember(matrix, matrix0, [type="version:Put",version:key="0",version:checkpoint="2",dot:hide2="true"])
# //entity(matrix1, [value="[10000, 0, 2]",type="script:list",label="[m, 0, 2]",script:line="4",dot:hide2="true"])
# //hadMember(matrix, matrix1, [type="version:Put",version:key="1",version:checkpoint="2",dot:hide2="true"])
# entity(matrix2#1, [value="[2, 10000, 0]",type="script:list",label="[2, m, 0]",script:line="5",dot:hide2="~attr"])
# hadMember(matrix2#1, 2, [type="version:Put",version:key="0",version:checkpoint="2",dot:hide2="true"])
# hadMember(matrix2#1, m, [type="version:Put",version:key="1",version:checkpoint="2",dot:hide2="true"])
# hadMember(matrix2#1, 0, [type="version:Put",version:key="2",version:checkpoint="2",dot:hide2="true"])
# //hadMember(matrix, matrix2, [type="version:Put",version:key="2",version:checkpoint="2",dot:hide2="true"])
#
# //entity(dist, [value="[[...]]",type="script:name",label="dist",script:line="2",dot:hide2="true"])
# //wasDerivedFrom(dist, matrix, -, -, -, [type="version:Reference",version:checkpoint="3",dot:hide2="true"])
#
# // L12#2
# entity(dist@i#2, [value="[2, 10000, 0]",type="script:access",label="dist[i]",script:line="12",dot:hide2="true"])
# wasDerivedFrom(dist@i#2, matrix2#1, -, -, -, [type="version:Reference",version:checkpoint="26",dot:hide2="true"])
# entity(disti#2, [value="[2, 10000, 0]",type="script:name",label="disti",script:line="12"])
# wasDerivedFrom(disti#2, dist@i#2, -, -, -, [type="version:Reference",version:checkpoint="27",dot:hide2="true"])
#
# // L13#2
# entity(j#5, [value="1",type="script:name",label="j",script:line="13"])
#
# // L15#2
# entity(ikj#2, [value="3",type="script:name",label="ikj",script:line="15"])
#
# // L16#2
# entity(disti@j#2, [value="10000",type="script:access",label="disti[j]",script:line="16",dot:hide2="~attr"])
# // wasDerivedFrom(disti@j#2, m, -, -, -, [type="version:Reference",version:checkpoint="34",version:collection="disti#2",version:key="0",version:access="r",dot:hide2="true"])
#
#
# // L17#1
#
# hadMember(matrix2#1, disti@j#3, [type="version:Put",version:key="1",version:checkpoint="36",dot:specific="true"])
# used(assign11, disti#2, -, [version:checkpoint="35",dot:specific="true"])
#
# entity(disti@j#3, [value="3",type="script:access",label="disti[j]",script:line="17"])
# activity(assign11, [type="script:assign"])
# wasDerivedFrom(disti@j#3, ikj#2, assign11, g31, u33, [type="version:Reference",version:checkpoint="36",version:collection="disti#2",version:key="1",version:access="w"])
# used(assign11, j#5, -)
# used(assign11, disti@j#2, -,[dot:hide2="true"])
# endDocument
# ##F##
