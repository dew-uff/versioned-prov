# %%
# %load_ext extensible_provn.prov_magics

# %%
# %%dot -o ../generated/graphs/graph -e png svg pdf
# digraph {
#     0 -> 1 [label="1"]
#     0 -> 2 [label="4"]
#     1 -> 2 [label="2"]
#     2 -> 0 [label="2"]
# }
