# %%
import sys
sys.path.insert(0, '../tools')

# %load_ext prov_magics

# %%
# %%dot -o ../images/graphs/graph -e png svg pdf
# digraph {
#     0 -> 1 [label="1"]
#     0 -> 2 [label="4"]
#     1 -> 2 [label="2"]
#     2 -> 1 [label="2"]
# }
